# %%
import os
import pandas as pd
import itertools
from datetime import datetime
import matplotlib.pyplot as plt

# %%
def read_raw_table(table_path):
    r = pd.read_excel(table_path, skiprows = 28, index_col = 0)
    
    df = r.loc[['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H'], :]
    df.index.name = None
    
    t = r.loc["End Time:", 1]
    t = datetime_object = datetime.strptime(t, '%d/%m/%Y %H:%M:%S')
    
    return df, t

# %%
df, t = read_raw_table("OD_readings/plate01/2023-07-06_19-54-11.xlsx")

# %%
wells = [f"{i[1]}{i[0]}" for i in itertools.product(range(1, 13), ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H'])]

# %%
plate = "plate01"
# well = wells[0]

fig, ax = plt.subplots()

for well in wells:
    vals = []
    ts = []
    for table_file in os.listdir(f"OD_readings/{plate}"):
        table_path = f"OD_readings/{plate}/{table_file}"
        df, t = read_raw_table(table_path)
        ts.append(t)
        val = df.loc[well[0], int(well[1:])]
        vals.append(val)
        
    ax.plot(ts, vals)

# %%
# %load_ext watermark
# %watermark -v -m -p pandas,matplotlib
print()
# %watermark -u -n -t -z
# Out:
# The watermark extension is already loaded. To reload it, use:
#   %reload_ext watermark
# Python implementation: CPython
# Python version       : 3.9.13
# IPython version      : 8.12.0
#
# pandas    : 1.5.1
# matplotlib: 3.6.2
#
# Compiler    : GCC 10.3.0
# OS          : Linux
# Release     : 5.15.0-76-generic
# Machine     : x86_64
# Processor   : x86_64
# CPU cores   : 8
# Architecture: 64bit
#
#
# Last updated: Sat Jul 08 2023 13:36:54+08
